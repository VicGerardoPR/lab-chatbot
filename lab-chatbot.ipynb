# %% [markdown]
# # **The Chat Format**
#
# In this notebook, you will explore how you can utilize the chat format to have extended conversations with chatbots personalized or specialized for specific tasks or behaviors.
#
# ## Setup

# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

OPENAI_API_KEY  = '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'

# %%
from dotenv import load_dotenv
import openai
import os

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def get_completion(prompt, model="gpt-3.5-turbo", temperature=2): 
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message.content


def get_completion_from_messages(message, model="gpt-3.5-turbo", temperature=2): 
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message.content

# %%
messages =  [  
{'role':'system', 'content':'You are an assistant that speaks like Shakespeare.'},    
{'role':'user', 'content':'tell me a joke'},   
{'role':'assistant', 'content':'Why did the chicken cross the road'},   
{'role':'user', 'content':'I don\'t know'}  ]

# %%
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# To get to the other side, methinks! Fare thee well, good sir or madam!

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Hi, my name is Isa'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Hello Isa! It's nice to meet you. How can I assist you today?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Yes,  can you remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I'm sorry, but I'm a text-based chatbot and I don't have the ability to remember personal information about users. How can I assist you today?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'Hi, my name is Isa'},
{'role':'assistant', 'content': "Hi Isa! It's nice to meet you. \
Is there anything I can help you with today?"},
{'role':'user', 'content':'Yes, you can remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Your name is Isa.

# %% [markdown]
# # OrderBot
# We can automate the collection of user prompts and assistant responses to build a  OrderBot. The OrderBot will take orders at a pizza restaurant.

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for a pizza restaurant. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  12.95, 10.00, 7.00 \
cheese pizza   10.95, 9.25, 6.50 \
eggplant pizza   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2d928d92-8eab-4d64-807a-a7cdeaf1b1ec'>
#   <div id="c015754c-7b40-45a6-bb96-c12e6165dd83" data-root-id="2d928d92-8eab-4d64-807a-a7cdeaf1b1ec" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# {
#   "pizza": {
#     "type": "pepperoni pizza",
#     "size": "medium"
#   },
#   "toppings": [
#     "extra cheese",
#     "mushrooms"
#   ],
#   "drinks": [
#     {
#       "type": "coke",
#       "size": "medium"
#     }
#   ],
#   "sides": [
#     {
#       "type": "fries",
#       "size": "regular"
#     }
#   ],
#   "total price": 23.45
# }

# %% [markdown]
# ## Try experimenting on your own!
#
# You can modify the menu or instructions to create your own orderbot!

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
messages = context.copy()
messages.append(
    {
        'role': 'system',
        'content': """Create a JSON summary of the previous food order.
        The JSON should contain:
        1) List of pizzas ordered, including size and price.
        2) List of toppings with price.
        3) List of drinks with size and price.
        4) List of sides with size and price.
        5) Total price of the order."""
    }
)

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# {
#     "Pizzas": [
#         {
#             "Pizza": "Pepperoni Pizza",
#             "Size": "Large",
#             "Price": 12.95
#         }
#     ],
#     "Toppings": [
#         {
#             "Extra Cheese": 2.00
#         }
#     ],
#     "Drinks": [
#         {
#             "Drink": "Bottled Water",
#             "Size": "Regular",
#             "Price": 5.00
#         }
#     ],
#     "Desserts": [
#         {
#             "Dessert": "Tiramisu",
#             "Price": 6.50
#         }
#     ],
#     "Total Price": 26.45
# }

# %%
messages = context.copy()
messages.append(
    {
        'role': 'system',
        'content': """Create a JSON summary of the previous electronics order.
        The JSON should contain:
        1) List of items purchased (e.g., laptops, smartphones, accessories).
        2) Specifications of each item (brand, model, storage capacity, color).
        3) List of additional accessories included.
        4) Total price of the order."""
    }
)

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# {
#     "items_purchased": [
#         {
#             "item": "Large Pepperoni Pizza with Extra Cheese"
#         },
#         {
#             "item": "Bottled Water"
#         },
#         {
#             "item": "Tiramisu"
#         }
#     ],
#     "total_price": "Total: $20.50",
#     "delivery_address": "123 Main Street"
# }

# %%
messages = context.copy()
messages.append(
    {
        'role': 'system',
        'content': """Create a JSON summary of the previous clothing order.
        The JSON should contain:
        1) List of clothing items purchased (e.g., shirts, pants, jackets).
        2) Size, color, and price for each item.
        3) List of accessories included (e.g., hats, belts, watches).
        4) Total price of the order."""
    }
)

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# {
#     "items": [
#         {
#             "item": "Large Pepperoni Pizza with Extra Cheese",
#             "price": 14.95
#         },
#         {
#             "item": "Bottled Water",
#             "price": 5.00
#         },
#         {
#             "item": "Tiramisu",
#             "price": 6.50
#         }
#     ],
#     "total": 26.45
# }
